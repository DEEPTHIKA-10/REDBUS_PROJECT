# %%
##SQL DATABASE:
# !pip install pandas
# %pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import mysql.connector
import numpy as np

# %%
# csv to dataframe
df_andhra=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\andhra_busdetails.csv")
df_kerala=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\kerala_busdetails.csv")
df_telangana=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\telangana_busdetails.csv")
df_haryana=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\haryana_busdetails.csv")
df_uttarpradesh=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\uttarpradesh_busdetails.csv")
df_rajasthan=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\rajasthan_busdetails.csv")
df_assam=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\assam_busdetails.csv")
df_meghalaya=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\meghalaya_busdetails.csv")
df_gujarat=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\gujarat_busdetails.csv")
df_punjab=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\punjab_busdetails.csv")
df_full1=pd.concat([df_andhra,df_kerala,df_telangana,df_haryana,df_uttarpradesh,df_rajasthan,df_assam,df_meghalaya,df_gujarat,df_punjab ],ignore_index=True)
df_full1
# Out:
#                     Bus_name                               Bus_type  \
# 0                   FRESHBUS              Electric A/C Seater (2+2)
# 1          IntrCity SmartBus             A/C Seater / Sleeper (2+1)
# 2          IntrCity SmartBus                       AC Sleeper (2+1)
# 3                   FRESHBUS                                    NaN
# 4                        NaN                                    NaN
# ...                      ...                                    ...
# 2036  PEPSU (Punjab) - 67121                  Volvo AC Seater (2+2)
# 2037          Laxmi holidays          Bharat Benz A/C Sleeper (2+1)
# 2038          Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)
# 2039          Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)
# 2040      New Navyug Travels                                    NaN
#
#      Start_time End_time Total_duration     Price     Seats_Available  \
# 0         22:35    05:40        07h 05m       328  27 Seats available
# ...

# %%
df_full1.columns
# Out:
# Index(['Bus_name', 'Bus_type', 'Start_time', 'End_time', 'Total_duration',
#        'Price', 'Seats_Available', 'Ratings', 'Route_link', 'Route_name',
#        'state'],
#       dtype='object')

# %%
df_full1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2041 entries, 0 to 2040
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1170 non-null   object
#  1   Bus_type         1150 non-null   object
#  2   Start_time       1170 non-null   object
#  3   End_time         1170 non-null   object
#  4   Total_duration   1170 non-null   object
#  5   Price            1168 non-null   object
#  6   Seats_Available  1154 non-null   object
#  7   Ratings          1164 non-null   object
#  8   Route_link       2041 non-null   object
#  9   Route_name       2041 non-null   object
#  10  state            2041 non-null   object
# dtypes: object(11)
# memory usage: 175.5+ KB

# %%
df_full1["Price"]
# Out:
# 0            328
# 1        INR 319
# 2        INR 499
# 3            328
# 4            NaN
#           ...
# 2036    INR 1107
# 2037     INR 600
# 2038     INR 414
# 2039     INR 414
# 2040         NaN
# Name: Price, Length: 2041, dtype: object

# %%
# Ensure all values in the column are strings
df_full1["Price"] = df_full1["Price"].astype(str)

# Remove "INR" and any other non-numeric characters
df_full1["Price"] = df_full1["Price"].str.replace("INR", "", regex=False).str.strip()

# Convert to numeric, coercing errors to NaN
df_full1["Price"] = pd.to_numeric(df_full1["Price"], errors="coerce")

# Fill NaN values with 0
df_full1["Price"] = df_full1["Price"].fillna(0)

# %%
df_full1["Ratings"]
# Out:
# 0       4.7\n577
# 1       4.6\n921
# 2       4.6\n880
# 3            4.7
# 4            NaN
#           ...
# 2036         3.7
# 2037    4.6\n105
# 2038    4.4\n291
# 2039    4.4\n102
# 2040         4.1
# Name: Ratings, Length: 2041, dtype: object

# %%
df_full1["Ratings"] = df_full1["Ratings"].astype(str)
df_full1["Ratings"] = df_full1["Ratings"].str.replace("New", "")
df_full1["Ratings"] = df_full1["Ratings"].str.strip()
df_full1["Ratings"] = df_full1["Ratings"].str.split().str[0]
# Convert to numeric, coercing errors
df_full1["Ratings"] = pd.to_numeric(df_full1["Ratings"], errors='coerce')
df_full1["Ratings"].fillna(0, inplace=True)

print(df_full1["Ratings"])
# Out:
# 0       4.7
# 1       4.6
# 2       4.6
# 3       4.7
# 4       0.0
#        ...
# 2036    3.7
# 2037    4.6
# 2038    4.4
# 2039    4.4
# 2040    4.1
# Name: Ratings, Length: 2041, dtype: float64
# C:\Users\kumar\AppData\Local\Temp\ipykernel_1340\1227998895.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_full1["Ratings"].fillna(0, inplace=True)

# %%
print(df_full1["Ratings"].unique())
# Out:
# [4.7 4.6 0.  3.8 3.  2.9 3.4 3.6 4.3 1.7 2.5 3.5 4.2 3.9 3.1 4.  4.4 3.2
#  4.5 3.7 4.1 2.3 2.8 3.3 2.7 2.2 4.8 1.5 2.6 2.1 2.4 1.6 1.  1.9 1.3 1.4
#  5.  4.9 2.  1.8 1.2]

# %%
print(df_full1["Bus_type"].unique())
# Out:
# ['Electric A/C Seater (2+2)' 'A/C Seater / Sleeper (2+1)'
#  'AC Sleeper (2+1)' nan 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)'
#  'INDRA(A.C. Seater)' 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)'
#  'Express Non AC Seater 2+3' 'ULTRA DELUXE (NON-AC, 2+2 PUSH BACK)'
#  'Non A/C Seater / Sleeper (2+1)' 'METRO LUXURY A/C'
#  'NIGHT RIDER (SEATER CUM SLEEPER)'
#  'Super Luxury (Non AC Seater 2+2 Push Back)' 'SAPTAGIRI EXPRESS'
#  'LAHARI A/C SLEEPER CUM SEATER' 'Super Fast Non AC Seater (2+3)'
#  'Low Floor AC Seater 2+2' 'Super Express Non AC Seater Air Bus (2+2)'
#  'Swift Deluxe Non AC Air Bus (2+2)' 'NON A/C Semi Sleeper (2+2)'
#  'A/C Semi Sleeper (2+2)' 'Bharat Benz A/C Seater /Sleeper (2+1)'
#  'A/C Sleeper (2+1)' 'AC MULTI AXLE' 'SWIFT-GARUDA A/C SEATER BUS'
#  'VE A/C Sleeper (2+1)' 'NON A/C Seater/ Sleeper (2+1)'
#  'Bharat Benz A/C Sleeper (2+1)' 'RAJDHANI (A.C. Semi Sleeper)'
#  'e-SUP LUXURY (2+2)' 'GARUDA PLUS (VOLVO / BENZ A.C Multi Axle)'
# ...

# %%
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Seater / Sleeper (2+1)", "AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Non A/C Seater / Sleeper (2+1)", "NON  AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("LAHARI A/C SLEEPER CUM SEATER", "AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Super Fast Non AC Seater (2+3)", " NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC Sleeper / Seater", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Electric A/C Seater (2+2)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("INDRA(A.C. Seater)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)", " NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("ULTRA DELUXE (NON-AC, 2+2 PUSH BACK)", "NON  AC Seater")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Express Non AC Seater 2+3", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("METRO LUXURY A/C", "AC Sleeper")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NIGHT RIDER (SEATER CUM SLEEPER)", "AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC Sleeper / Seater", "AC Sleeper")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Super Luxury (Non AC Seater 2+2 Push Back)", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("SAPTAGIRI EXPRESS", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Low Floor AC Seater 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Super Express Non AC Seater Air Bus (2+2)", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Swift Deluxe Non AC Air Bus (2+2)", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON A/C Semi Sleeper (2+2)", "NON  AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz A/C Seater /Sleeper (2+1)", "AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Sleeper (2+1)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC MULTI AXLE", "AC Sleeper")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("SWIFT-GARUDA A/C SEATER BUS", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE A/C Sleeper (2+1)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON A/C Seater/ Sleeper (2+1)", "NON  AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz A/C Sleeper (2+1)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("RAJDHANI (A.C. Semi Sleeper)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("e-SUP LUXURY (2+2)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("GARUDA PLUS (VOLVO / BENZ A.C Multi Axle)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Lahari A/C sleeper", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Deluxe (Non AC Seater 2+2)", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Ordinary 3+2 Non AC Seater", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Himsuta AC Seater Volvo/Scania 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Executive (2+3)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz A/C Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Scania Multi-Axle AC Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Seater (2+2)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo A/C Semi Sleeper (2+2)", "AC Semi Sleeper")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo 9600 Multi Axle Semi-Sleeper (2+2)", "AC Semi Sleeper") 
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Himmani Deluxe 2+2 Non AC Seater", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE A/C Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Scania A/C Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Super Luxury Volvo AC Seater Pushback 2+2'", "AC Seater")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Mercedes Multi-Axle Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo A/C Semi Sleeper (2+2 )", "AC  Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo AC Seater 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Ordinary Non AC Seater 2+3", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Janrath AC Seater 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace(" Shatabdi AC Seater 2+2", "A/C Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Pink Express AC Seater 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Seater/Sleeper (2+1)", "AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE A/C Seater (2+2)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz A/C Seater (2+2)'", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Rajdhani Non AC Seater 2+3", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Seater / Sleeper (2+2)", "AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC Seater (2+2)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE A/C Seater / Sleeper (2+1)", "AC Sleeper / Seater")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE A/C Seater / Sleeper (2+2)", "AC  Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Janrath AC Seater 2+3", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON A/C Seater Push Back (2+2)", " NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON A/C Sleeper (2+1)", "NON - AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo Multi Axle B11R AC Seater\\Sleeper (2+1)", "AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("SHATABDI (2+3)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Semi Deluxe Non AC Seater 2+2", " NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON AC Seater / Sleeper 2+1", "NON  AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Deluxe AC Seater 2+2", "AC Seater")                    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON AC Seater/ Sleeper (2+1)", "NON  AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo Multi-Axle I-Shift A/C Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo 9600 Multi-Axle A/C Sleeper (2+1)", "AC Sleeper")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Non AC Seater (2+2)", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Non AC Seater (2+1)", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON A/C Seater Push Back (2+1)", "NON  AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz A/C Seater (2+1)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Seater (2+1)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON A/C Seater / Sleeper (2+2)", "NON  AC Sleeper / Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Tata A/C Seater Executive Luxury (2+2)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Tata Non A/C Seater Executive Luxury (2+2)", "NON  AC Seater")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("A/C Volvo B11R Multi-Axle Sleeper (2+1)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo Multi Axle Sleeper B11R (2+1)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC Seater Hvac 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo A/C Sleeper (2+1)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Mercedes A/C Semi Sleeper (2+2)", "AC Semi Sleeper")    
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo AC Seater (2+2)", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo Multi-Axle A/C Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC Sleeper (2+1)", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE AC Sleeper", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz AC Sleeper","AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz AC Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo AC Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE AC Semi Sleeper", "AC Semi Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Scania AC Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Super Luxury Volvo AC Seater Pushback 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC  Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo 9600 AC Semi Sleeper", "AC  Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Shatabdi AC Seater 2+2", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("VE AC Seater", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo Multi-Axle I-Shift AC Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo 9600 Multi-Axle AC Sleeper'", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Bharat Benz AC Seater", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo AC Sleeper", "AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Mercedes AC Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo AC Seater", "AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo Multi-Axle AC Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Volvo 9600 Multi-Axle AC Sleeper", "AC Sleeper")

# %%
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Non AC Sleeper", "NON AC Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("Non AC Seater", "NON AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON  AC Seater", "NON AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC  Semi Sleeper", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("AC Semi Seater", "AC Semi Sleeper")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace(" NON AC Seater", "NON AC Seater")
df_full1["Bus_type"]=df_full1["Bus_type"].str.replace("NON  AC Sleeper / Seater", "NON AC Sleeper / Seater")

# %%
df_full1["Bus_type"].fillna("0",inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_1340\3729251060.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_full1["Bus_type"].fillna("0",inplace=True)

# %%
print(df_full1["Bus_type"].unique())
# Out:
# ['AC Seater' 'AC Sleeper' '0' 'NON AC Seater' 'NON AC Sleeper'
#  'NON  AC Semi Sleeper' 'AC Semi Sleeper' 'AC Sleeper / Seater'
#  'NON AC Sleeper / Seater']

# %%
df_full1
# Out:
#                     Bus_name             Bus_type Start_time End_time  \
# 0                   FRESHBUS            AC Seater      22:35    05:40
# 1          IntrCity SmartBus           AC Sleeper      23:05    06:00
# 2          IntrCity SmartBus           AC Sleeper      23:50    06:00
# 3                   FRESHBUS                    0      18:00    23:40
# 4                        NaN                    0        NaN      NaN
# ...                      ...                  ...        ...      ...
# 2036  PEPSU (Punjab) - 67121            AC Seater      21:00    06:05
# 2037          Laxmi holidays           AC Sleeper      23:40    07:10
# 2038          Laxmi holidays  AC Sleeper / Seater      22:00    05:45
# 2039          Laxmi holidays  AC Sleeper / Seater      22:20    05:30
# 2040      New Navyug Travels                    0      22:45    05:15
#
#      Total_duration   Price     Seats_Available  Ratings  \
# 0           07h 05m   328.0  27 Seats available      4.7
# ...

# %%
df_full1.fillna(0,inplace=True)

# %%
df_full1.drop_duplicates(inplace=True)

# %%
df_full1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1329 entries, 0 to 2040
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1329 non-null   object
#  1   Bus_type         1329 non-null   object
#  2   Start_time       1329 non-null   object
#  3   End_time         1329 non-null   object
#  4   Total_duration   1329 non-null   object
#  5   Price            1329 non-null   float64
#  6   Seats_Available  1329 non-null   object
#  7   Ratings          1329 non-null   float64
#  8   Route_link       1329 non-null   object
#  9   Route_name       1329 non-null   object
#  10  state            1329 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 124.6+ KB

# %%
import pandas as pd
df_full1.to_csv(r"C:\Users\kumar\Desktop\scraped_data\complete_busdetails_cleaned.csv",index=False)
df_full1
# Out:
#                     Bus_name             Bus_type Start_time End_time  \
# 0                   FRESHBUS            AC Seater      22:35    05:40
# 1          IntrCity SmartBus           AC Sleeper      23:05    06:00
# 2          IntrCity SmartBus           AC Sleeper      23:50    06:00
# 3                   FRESHBUS                    0      18:00    23:40
# 4                          0                    0          0        0
# ...                      ...                  ...        ...      ...
# 2036  PEPSU (Punjab) - 67121            AC Seater      21:00    06:05
# 2037          Laxmi holidays           AC Sleeper      23:40    07:10
# 2038          Laxmi holidays  AC Sleeper / Seater      22:00    05:45
# 2039          Laxmi holidays  AC Sleeper / Seater      22:20    05:30
# 2040      New Navyug Travels                    0      22:45    05:15
#
#      Total_duration   Price     Seats_Available  Ratings  \
# 0           07h 05m   328.0  27 Seats available      4.7
# ...

# %% [markdown]
# CREATING MYSQL DATABASE:

# %%
import mysql.connector

# Establish connection
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="REDBUS"
)

cursor = conn.cursor()
cursor.execute("SHOW TABLES;")

for table in cursor:
    print(table)

cursor.close()
conn.close()

# %% [markdown]
# TABLE CREATION

# %%
import pymysql

# Connect to MySQL
conn = pymysql.connect(
    host="localhost",
    user="root",
    password="",  # Default XAMPP MySQL password is empty
    database="REDBUS",
    port=3306
)

# Create a cursor object
my_cursor = conn.cursor()

# Create table query
create_table_query = """
CREATE TABLE IF NOT EXISTS bus_details (
    ID INT AUTO_INCREMENT PRIMARY KEY,
    Bus_name VARCHAR(255) NOT NULL,
    Bus_type VARCHAR(255) NOT NULL,
    Start_time VARCHAR(255) NOT NULL,
    End_time VARCHAR(255) NOT NULL,
    Total_duration VARCHAR(255) NOT NULL,
    Price FLOAT DEFAULT 0,
    Seats_Available VARCHAR(255) NOT NULL,
    Ratings FLOAT NULL,
    routelink VARCHAR(255) NULL,
    route VARCHAR(255) NULL,
    state TEXT NOT NULL
);
"""

# Execute the query
my_cursor.execute(create_table_query)

print("✅ MySQL Table 'bus_details' created successfully in 'redbus' database!")

# Commit changes and close connection
#conn.commit()
#my_cursor.close()
#conn.close()
# Out:
# ✅ MySQL Table 'bus_details' created successfully in 'redbus' database!

# %%
import pandas as pd 
df_full1=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\complete_busdetails_cleaned.csv")
df_full1
# Out:
#                     Bus_name             Bus_type Start_time End_time  \
# 0                   FRESHBUS            AC Seater      22:35    05:40
# 1          IntrCity SmartBus           AC Sleeper      23:05    06:00
# 2          IntrCity SmartBus           AC Sleeper      23:50    06:00
# 3                   FRESHBUS                    0      18:00    23:40
# 4                          0                    0          0        0
# ...                      ...                  ...        ...      ...
# 1324  PEPSU (Punjab) - 67121            AC Seater      21:00    06:05
# 1325          Laxmi holidays           AC Sleeper      23:40    07:10
# 1326          Laxmi holidays  AC Sleeper / Seater      22:00    05:45
# 1327          Laxmi holidays  AC Sleeper / Seater      22:20    05:30
# 1328      New Navyug Travels                    0      22:45    05:15
#
#      Total_duration   Price     Seats_Available  Ratings  \
# 0           07h 05m   328.0  27 Seats available      4.7
# ...

# %%
insert_query = """
INSERT INTO bus_details (
    Bus_name,
    Bus_type,
    Start_time,
    End_time,
    Total_duration,
    Price,
    Seats_Available,
    Ratings,
    routelink,
    route,
    state
)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s)
ON DUPLICATE KEY UPDATE
    Bus_type = VALUES(Bus_type),
    End_time = VALUES(End_time),
    Total_duration = VALUES(Total_duration),
    Price = VALUES(Price),
    Seats_Available = VALUES(Seats_Available),
    Ratings = VALUES(Ratings),
    routelink = VALUES(routelink),
    state = VALUES(state);
"""

data=df_full1.values.tolist()
my_cursor.executemany(insert_query,data)
conn.commit()

# %%
my_cursor.execute("SELECT  COUNT(DISTINCT route) AS RouteCount  FROM bus_details")
rows = my_cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (282,)

# %%
#mycursor.execute("DELETE FROM bus_details WHERE Bus_name IS NULL OR Bus_type IS NULL OR Price IS NULL")
my_cursor.execute("DELETE FROM bus_details WHERE Bus_name = '0' OR Bus_type = '0' OR Price = '0'")
conn.commit()  
print("Rows with NULL values in Bus_name, Bus_type, or Price have been deleted.")
# Out:
# Rows with NULL values in Bus_name, Bus_type, or Price have been deleted.

# %%
my_cursor.execute("SELECT * FROM bus_details")  
rows = my_cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'FRESHBUS', 'AC Seater', '22:35', '05:40', '07h 05m', 328.0, '27 Seats available', 4.7, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada', 'APSRTC')
# (2, 'IntrCity SmartBus', 'AC Sleeper', '23:05', '06:00', '06h 55m', 319.0, '27 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada', 'APSRTC')
# (3, 'IntrCity SmartBus', 'AC Sleeper', '23:50', '06:00', '06h 10m', 499.0, '17 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada', 'APSRTC')
# (6, 'APSRTC - 35133', 'AC Sleeper', '16:00', '21:55', '05h 55m', 720.0, '34 Seats available', 3.8, 'https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad', 'Vijayawada to Hyderabad', 'APSRTC')
# (7, 'APSRTC - 35271', 'AC Seater', '16:00', '22:05', '06h 05m', 567.0, '31 Seats available', 3.0, 'https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad', 'Vijayawada to Hyderabad', 'APSRTC')
# ...

# %%
my_cursor.execute("SHOW COLUMNS FROM bus_details")
columns = my_cursor.fetchall()
print("Available columns:", [col[0] for col in columns])
# Out:
# Available columns: ['ID', 'Bus_name', 'Bus_type', 'Start_time', 'End_time', 'Total_duration', 'Price', 'Seats_Available', 'Ratings', 'routelink', 'route', 'state']
